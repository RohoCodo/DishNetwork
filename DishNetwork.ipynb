# %%
import json
categories = ['id', 'cuisine', 'ingredients', 'tp_cat', 'tp_numeric']
with open('DishTrain.json') as f:
    data = json.load(f)

counter = 0
for dishes in data:
    for cat in categories:
        print(str(counter) + ": " + cat + " : " + str(dishes[cat]))
    counter += 1
# Out:
# 0: id : 10259
# 0: cuisine : greek
# 0: ingredients : [u'romaine lettuce', u'black olives', u'grape tomatoes', u'garlic', u'pepper', u'purple onion', u'seasoning', u'garbanzo beans', u'feta cheese crumbles']
# 0: tp_cat : [u'pungent smell, peppery/hot taste and health friendly', u'', u'', u'', u'', u'-1', u'']
# 0: tp_numeric : [1, 0, 0, 0, 0, 0, 1]
# 1: id : 25693
# 1: cuisine : southern_us
# 1: ingredients : [u'plain flour', u'ground pepper', u'salt', u'tomatoes', u'ground black pepper', u'thyme', u'eggs', u'green tomatoes', u'yellow corn meal', u'milk', u'vegetable oil']
# 1: tp_cat : [u'sharp, penetrating aroma and a characteristic woody, piney flavor', u'vegetable oil', u'salt', u'', u'', u'eggs and milk', u'']
# 1: tp_numeric : [2, 2, 1, 0, 0, 0, 0]
# 2: id : 20130
# 2: cuisine : filipino
# ...
